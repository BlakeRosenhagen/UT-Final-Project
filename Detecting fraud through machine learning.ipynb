# %%
#pip install xgboost
#!pip install graphviz

# %%
import prep
import training_testing

# %%
run prep
# Out:
# Data Preparation Complete

# %%
#This takes some time as it has to go through quite a few processes.
#Estimated time: 5 min
# %run training_testing
# Out:
# Train dataset contains 2216327 rows and 7 columns
# Test dataset contains 554082 rows and 7 columns
# == XGB Decision Tree Metrics==
# Accuracy: 0.98
# Log loss: 0.06
# Model accuracy (AUPRC) = 89.72%
# Error: 0.0242
